# %% [markdown]
# 1. 1
#
# purpose：label
# log：IQRVars
# std：standardization
# select：forward  ->  'purpose', 'inq.last.6mths', 'credit.policy', 'fico', 'int.rate'
#
#
# - easy_model
#
# | Index | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-------|-----------------------|----------|-----------|--------|----------|---------------|
# | 0     | Logistic Regression   | 58       | 65.3846   | 34     | 44.7368  | 0.641813      |
# | 1     | Decision Tree         | 55       | 55.3191   | 52     | 53.6082  | 0.575969      |
# | 2     | Random Forest         | 65       | 70.2703   | 52     | 59.7701  | 0.607308      |
# | 3     | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.656491      |
# | 4     | Gradient Boosting     | 63       | 74.0741   | 40     | 51.9481  | 0.644595      |
# | 5     | Neural Network        | 62       | 75.0000   | 36     | 48.6486  | 0.650141      |
# | 6     | Voting Classifier     | 63       | 74.0741   | 40     | 51.9481  | 0.656095      |
# | 7     | Bagging Classifier    | 59       | 60.9756   | 50     | 54.9451  | 0.601749      |
# | 8     | XGBoost Classifier    | 56       | 57.8947   | 44     | 50       | 0.609290      |
# | 9     | LightGBM              | 60       | 67.8571   | 38     | 48.7179  | 0.622775      |
#
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 58       | 65.3846   | 34     | 44.7368  | 0.641813      | {'C': 1, 'penalty': 'l2'}                        |
# | Decision Tree         | 61       | 67.7419   | 42     | 51.8519  | 0.650145      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 60       | 67.8571   | 38     | 48.7179  | 0.643791      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200} |
# | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.656491      | {'C': 1, 'kernel': 'rbf'}                        |
# | Gradient Boosting     | 63       | 74.0741   | 40     | 51.9481  | 0.649751      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
# | Neural Network        | 62       | 71.4286   | 36     | 48.6486  | 0.654903      | {'alpha': 0.001, 'hidden_layer_sizes': (50,)}    |
# | Voting Classifier     | 63       | 74.0741   | 40     | 51.9481  | 0.654141      | {}                                               |
# | Bagging Classifier    | 61       | 64.8649   | 48     | 55.1724  | 0.619206      | {'max_samples': 0.5, 'n_estimators': 50}         |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.650939      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 59       | 73.6842   | 28     | 40.5797  | 0.652522      | {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}    |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.59     | 0.653846  | 0.34   | 0.447368 | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.63     | 0.692308  | 0.36   | 0.473684 | {'max_depth': 10, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.65     | 0.676471  | 0.46   | 0.547619 | {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 2}                 |
# | SVM                   | 0.63     | 0.740741  | 0.4    | 0.519481 | {'C': 10, 'kernel': 'rbf'}                                                      |
# | Gradient Boosting     | 0.63     | 0.541667  | 0.52   | 0.530612 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}                       |
# | Neural Network        | 0.63     | 0.666667  | 0.36   | 0.467532 | {'hidden_layer_sizes': (100,), 'alpha': 0.01}                                    |
# | Voting Classifier     | 0.63     | 0.740741  | 0.4    | 0.519481 | {}                                                                               |
# | Bagging Classifier    | 0.7      | 0.609756  | 0.5    | 0.549451 | {'n_estimators': 50, 'max_samples': 0.7}                                         |
# | XGBoost Classifier    | 0.63     | 0.547619  | 0.46   | 0.5      | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                       |
# | LightGBM              | 0.66     | 0.545455  | 0.48   | 0.510638 | {'n_estimators': 200, 'learning_rate': 1, 'max_depth': 3}                        |

# %% [markdown]
# 1. 2
# purpose：label
# log：IQRVars
# std：standardization
# select：lasso  ->  'credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc', 'fico', 'inq.last.6mths'
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 56       | 62.5      | 30     | 40.5405  | 0.641018      |
# | Decision Tree         | 54       | 54.7619   | 46     | 50       | 0.565257      |
# | Random Forest         | 60       | 67.8571   | 38     | 48.7179  | 0.615234      |
# | SVM                   | 60       | 66.6667   | 40     | 50       | 0.648555      |
# | Gradient Boosting     | 62       | 73.0769   | 38     | 50       | 0.642203      |
# | Neural Network        | 57       | 64        | 32     | 42.6667  | 0.651333      |
# | Voting Classifier     | 62       | 71.4286   | 40     | 51.2821  | 0.650142      |
# | Bagging Classifier    | 60       | 69.2308   | 36     | 47.3684  | 0.605707      |
# | XGBoost Classifier    | 58       | 64.2857   | 36     | 46.1538  | 0.602938      |
# | LightGBM              | 59       | 68        | 34     | 45.3333  | 0.622368      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 56       | 62.5      | 30     | 40.5405  | 0.641415      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 61       | 68.9655   | 40     | 50.6329  | 0.643796      | {'max_depth': 5, 'min_samples_split': 10}        |
# | Random Forest         | 65       | 82.6087   | 38     | 52.0548  | 0.641419      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200} |
# | SVM                   | 60       | 66.6667   | 40     | 50       | 0.648555      | {'C': 1, 'kernel': 'rbf'}                        |
# | Gradient Boosting     | 60       | 67.8571   | 38     | 48.7179  | 0.644987      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 59       | 68        | 34     | 45.3333  | 0.65411       | {'alpha': 0.01, 'hidden_layer_sizes': (50,)}     |
# | Voting Classifier     | 62       | 71.4286   | 40     | 51.2821  | 0.650142      | {}                                               |
# | Bagging Classifier    | 62       | 71.4286   | 40     | 51.2821  | 0.624357      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.650938      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 60       | 67.8571   | 38     | 48.7179  | 0.652128      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
#
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.56     | 0.625     | 0.3    | 0.405405 | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.61     | 0.541667  | 0.26   | 0.351351 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.65     | 0.678571  | 0.38   | 0.487179 | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5}                   |
# | SVM                   | 0.60     | 0.62963   | 0.34   | 0.441558 | {'C': 1, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting     | 0.62     | 0.588235  | 0.4    | 0.47619  | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3}                     |
# | Neural Network        | 0.59     | 0.555556  | 0.3    | 0.38961  | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                                  |
# | Voting Classifier     | 0.62     | 0.714286  | 0.4    | 0.512821 | {}                                                                               |
# | Bagging Classifier    | 0.62     | 0.692308  | 0.36   | 0.473684 | {'n_estimators': 100, 'max_samples': 0.5}                                       |
# | XGBoost Classifier    | 0.66     | 0.59375   | 0.38   | 0.463415 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}                     |
# | LightGBM              | 0.65     | 0.6       | 0.42   | 0.494118 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}                     |

# %% [markdown]
# 1. 3
# purpose：label
# log：IQRVars
# std：standardization
# select：kbest10  ->  'credit.policy', 'purpose', 'int.rate', 'installment', 'dti', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', pub.rec
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 54       | 57.1429   | 32     | 41.0256  | 0.646176      |
# | Decision Tree         | 55       | 57.5758   | 38     | 45.7831  | 0.559323      |
# | Random Forest         | 59       | 63.6364   | 42     | 50.6024  | 0.612456      |
# | SVM                   | 61       | 70.3704   | 38     | 49.3506  | 0.642999      |
# | Gradient Boosting     | 59       | 66.6667   | 36     | 46.7532  | 0.63785       |
# | Neural Network        | 56       | 58.8235   | 40     | 47.619   | 0.640215      |
# | Voting Classifier     | 60       | 67.8571   | 38     | 48.7179  | 0.646172      |
# | Bagging Classifier    | 57       | 61.2903   | 38     | 46.9136  | 0.610479      |
# | XGBoost Classifier    | 56       | 58.3333   | 42     | 48.8372  | 0.600156      |
# | LightGBM              | 59       | 63.6364   | 42     | 50.6024  | 0.610875      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 54       | 57.1429   | 32     | 41.0256  | 0.646176      | {'C': 1, 'penalty': 'l2'}                        |
# | Decision Tree         | 60       | 66.6667   | 40     | 50       | 0.629912      | {'max_depth': 5, 'min_samples_split': 10}        |
# | Random Forest         | 61       | 68.9655   | 40     | 50.6329  | 0.646175      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200} |
# | SVM                   | 57       | 65.2174   | 30     | 41.0959  | 0.643398      | {'C': 0.1, 'kernel': 'rbf'}                      |
# | Gradient Boosting     | 58       | 66.6667   | 32     | 43.2432  | 0.642606      | {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200}    |
# | Neural Network        | 57       | 60.6061   | 40     | 48.1928  | 0.648151      | {'alpha': 0.01, 'hidden_layer_sizes': (50,)}     |
# | Voting Classifier     | 59       | 65.5172   | 38     | 48.1013  | 0.645383      | {}                                               |
# | Bagging Classifier    | 56       | 58.3333   | 42     | 48.8372  | 0.630799      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.646972      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 60       | 69.2308   | 36     | 47.3684  | 0.648554      | {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 200}    |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.55     | 0.551724  | 0.32   | 0.405063 | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.60     | 0.611111  | 0.44   | 0.511628 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.64     | 0.677419  | 0.42   | 0.518519 | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2}                   |
# | SVM                   | 0.61     | 0.62069   | 0.36   | 0.455696 | {'C': 1, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting     | 0.61     | 0.538462  | 0.42   | 0.47191  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3}                    |
# | Neural Network        | 0.57     | 0.548387  | 0.34   | 0.419753 | {'hidden_layer_sizes': (50,), 'alpha': 0.01}                                    |
# | Voting Classifier     | 0.58     | 0.633333  | 0.38   | 0.475    | {}                                                                               |
# | Bagging Classifier    | 0.64     | 0.612903  | 0.38   | 0.469136 | {'n_estimators': 100, 'max_samples': 0.7}                                       |
# | XGBoost Classifier    | 0.62     | 0.534884  | 0.46   | 0.494624 | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3}                     |
# | LightGBM              | 0.63     | 0.55      | 0.44   | 0.488889 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3}                     |

# %% [markdown]
# 1. 4
#
# purpose：label
# log：IQRVars
# std：standardization
# select：ridge (all)
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.646970      |
# | Decision Tree         | 51       | 51.2821   | 40     | 44.9438  | 0.557328      |
# | Random Forest         | 59       | 64.5161   | 40     | 49.3827  | 0.627532      |
# | SVM                   | 58       | 64.2857   | 36     | 46.1538  | 0.638240      |
# | Gradient Boosting     | 62       | 70        | 42     | 52.5     | 0.639037      |
# | Neural Network        | 54       | 57.1429   | 32     | 41.0256  | 0.631495      |
# | Voting Classifier     | 57       | 62.069    | 36     | 45.5696  | 0.642999      |
# | Bagging Classifier    | 62       | 73.0769   | 38     | 50       | 0.625549      |
# | XGBoost Classifier    | 55       | 58.6207   | 34     | 43.083   | 0.60651       |
# | LightGBM              | 60       | 66.6667   | 40     | 50       | 0.623165      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.649349      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 60       | 66.6667   | 40     | 50       | 0.630312      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 63       | 74.0741   | 40     | 51.9481  | 0.649342      | {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100} |
# | SVM                   | 56       | 63.6364   | 28     | 38.8889  | 0.63983       | {'C': 0.1, 'kernel': 'rbf'}                      |
# | Gradient Boosting     | 60       | 67.8571   | 38     | 48.7179  | 0.644191      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 52       | 53.3333   | 32     | 40       | 0.647357      | {'alpha': 0.0001, 'hidden_layer_sizes': (50,)}   |
# | Voting Classifier     | 56       | 59.375    | 38     | 46.3415  | 0.642207      | {}                                               |
# | Bagging Classifier    | 62       | 70        | 42     | 52.5     | 0.628326      | {'max_samples': 0.7, 'n_estimators': 100}        |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.641813      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 61       | 70.3704   | 38     | 49.3506  | 0.644196      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.56     | 0.538462  | 0.28   | 0.368421 | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.60     | 0.571429  | 0.40   | 0.470588 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.63     | 0.724138  | 0.42   | 0.531646 | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2}                   |
# | SVM                   | 0.58     | 0.612903  | 0.38   | 0.469136 | {'C': 0.1, 'kernel': 'linear'}                                                  |
# | Gradient Boosting     | 0.64     | 0.636364  | 0.42   | 0.506024 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | Neural Network        | 0.56     | 0.59375   | 0.38   | 0.463415 | {'hidden_layer_sizes': (50, 50), 'alpha': 0.01}                                 |
# | Voting Classifier     | 0.60     | 0.678571  | 0.40   | 0.487179 | {}                                                                               |
# | Bagging Classifier    | 0.62     | 0.730769  | 0.38   | 0.50     | {'n_estimators': 100, 'max_samples': 0.7}                                       |
# | XGBoost Classifier    | 0.66     | 0.59375   | 0.36   | 0.463415 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | LightGBM              | 0.63     | 0.689655  | 0.40   | 0.506329 | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}                    |

# %% [markdown]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# 2. 1
#
# purpose：label
# log：logVars
# std：standardization
# select：forward  ->  'purpose', 'inq.last.6mths', 'credit.policy', 'fico', 'int.rate'
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 59       | 68.0000   | 34     | 45.3333  | 0.641018      |
# | Decision Tree         | 54       | 57.6923   | 30     | 39.4737  | 0.600952      |
# | Random Forest         | 55       | 58.0645   | 36     | 44.4444  | 0.591830      |
# | SVM                   | 59       | 65.5172   | 38     | 48.1013  | 0.651731      |
# | Gradient Boosting     | 62       | 77.2727   | 34     | 47.2222  | 0.650933      |
# | Neural Network        | 60       | 69.2308   | 36     | 47.3684  | 0.645383      |
# | Voting Classifier     | 60       | 67.8571   | 38     | 48.7179  | 0.643006      |
# | Bagging Classifier    | 57       | 61.2903   | 38     | 46.9136  | 0.596192      |
# | XGBoost Classifier    | 55       | 58.0645   | 36     | 44.4444  | 0.611661      |
# | LightGBM              | 59       | 68.0000   | 34     | 45.3333  | 0.616818      |
#
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 59       | 68        | 34     | 45.3333  | 0.641414      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 59       | 84.6154   | 22     | 34.9206  | 0.635859      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 59       | 65.5172   | 38     | 48.1013  | 0.631889      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 50}  |
# | SVM                   | 61       | 72        | 36     | 48       | 0.655302      | {'C': 10, 'kernel': 'rbf'}                       |
# | Gradient Boosting     | 60       | 69.2308   | 36     | 47.3684  | 0.652122      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
# | Neural Network        | 60       | 69.2308   | 36     | 47.3684  | 0.651334      | {'alpha': 0.01, 'hidden_layer_sizes': (50,)}     |
# | Voting Classifier     | 60       | 67.8571   | 38     | 48.7179  | 0.648155      | {}                                               |
# | Bagging Classifier    | 52       | 53.3333   | 32     | 40       | 0.598163      | {'max_samples': 0.5, 'n_estimators': 10}         |
# | XGBoost Classifier    | 60       | 69.2308   | 36     | 47.3684  | 0.651373      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 62       | 75        | 36     | 48.6486  | 0.651332      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.60     | 0.68      | 0.34   | 0.453333 | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.59     | 0.62963   | 0.34   | 0.441558 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.63     | 0.586207  | 0.34   | 0.43038  | {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 5}                  |
# | SVM                   | 0.61     | 0.72      | 0.36   | 0.48     | {'C': 10, 'kernel': 'rbf'}                                                      |
# | Gradient Boosting     | 0.62     | 0.594595  | 0.44   | 0.505747 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}                      |
# | Neural Network        | 0.61     | 0.708333  | 0.34   | 0.459459 | {'hidden_layer_sizes': (50, 50), 'alpha': 0.0001}                               |
# | Voting Classifier     | 0.59     | 0.666667  | 0.36   | 0.467532 | {}                                                                               |
# | Bagging Classifier    | 0.59     | 0.612903  | 0.38   | 0.469136 | {'n_estimators': 50, 'max_samples': 0.7}                                        |
# | XGBoost Classifier    | 0.63     | 0.612903  | 0.38   | 0.469136 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | LightGBM              | 0.62     | 0.545455  | 0.36   | 0.433735 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}                      |

# %% [markdown]
# 2. 2
#
# purpose：label
# log：logVars
# std：standardization
# select：lasso  ->  'credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc', 'fico', 'inq.last.6mths'
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 56       | 62.5000   | 30     | 40.5405  | 0.640225      |
# | Decision Tree         | 54       | 54.7619   | 46     | 50.0000  | 0.562878      |
# | Random Forest         | 61       | 68.9655   | 40     | 50.6329  | 0.614441      |
# | SVM                   | 60       | 66.6667   | 40     | 50.0000  | 0.648158      |
# | Gradient Boosting     | 61       | 70.3704   | 38     | 49.3506  | 0.642600      |
# | Neural Network        | 58       | 65.3846   | 34     | 44.7368  | 0.648557      |
# | Voting Classifier     | 62       | 71.4286   | 40     | 51.2821  | 0.648556      |
# | Bagging Classifier    | 60       | 69.2308   | 36     | 47.3684  | 0.605709      |
# | XGBoost Classifier    | 58       | 64.2857   | 36     | 46.1538  | 0.602938      |
# | LightGBM              | 59       | 68.0000   | 34     | 45.3333  | 0.622368      |
#
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 56       | 62.5      | 30     | 40.5405  | 0.641018      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 61       | 68.9655   | 40     | 50.6329  | 0.643796      | {'max_depth': 5, 'min_samples_split': 10}        |
# | Random Forest         | 65       | 82.6087   | 38     | 52.0548  | 0.64142       | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200} |
# | SVM                   | 60       | 66.6667   | 40     | 50       | 0.648158      | {'C': 1, 'kernel': 'rbf'}                        |
# | Gradient Boosting     | 60       | 67.8571   | 38     | 48.7179  | 0.644987      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 57       | 64        | 32     | 42.6667  | 0.653317      | {'alpha': 0.001, 'hidden_layer_sizes': (50,)}    |
# | Voting Classifier     | 62       | 71.4286   | 40     | 51.2821  | 0.648159      | {}                                               |
# | Bagging Classifier    | 62       | 71.4286   | 40     | 51.2821  | 0.622372      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.650938      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 60       | 67.8571   | 38     | 48.7179  | 0.652128      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.56     | 0.625     | 0.30   | 0.405405 | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.61     | 0.541667  | 0.26   | 0.351351 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.65     | 0.678571  | 0.38   | 0.487179 | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5}                   |
# | SVM                   | 0.60     | 0.653846  | 0.34   | 0.447368 | {'C': 1, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting     | 0.62     | 0.588235  | 0.40   | 0.47619  | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7}                    |
# | Neural Network        | 0.59     | 0.6       | 0.30   | 0.4      | {'hidden_layer_sizes': (50,), 'alpha': 0.01}                                    |
# | Voting Classifier     | 0.61     | 0.689655  | 0.40   | 0.506329 | {}                                                                               |
# | Bagging Classifier    | 0.62     | 0.692308  | 0.36   | 0.473684 | {'n_estimators': 100, 'max_samples': 0.5}                                       |
# | XGBoost Classifier    | 0.66     | 0.59375   | 0.38   | 0.463415 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}                     |
# | LightGBM              | 0.65     | 0.6       | 0.42   | 0.494118 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}                     |

# %% [markdown]
# 2. 3
#
# purpose：label
# log：logVars
# std：standardization
# select：kbest10  ->  'credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', pub.rec
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.646571      |
# | Decision Tree         | 57       | 58.1395   | 50     | 53.7634  | 0.557314      |
# | Random Forest         | 58       | 64.2857   | 36     | 46.1538  | 0.629121      |
# | SVM                   | 58       | 64.2857   | 36     | 46.1538  | 0.643788      |
# | Gradient Boosting     | 59       | 66.6667   | 36     | 46.7532  | 0.637839      |
# | Neural Network        | 54       | 55.5556   | 40     | 46.5116  | 0.642995      |
# | Voting Classifier     | 57       | 62.0690   | 36     | 45.5696  | 0.645773      |
# | Bagging Classifier    | 60       | 66.6667   | 40     | 50.0000  | 0.614436      |
# | XGBoost Classifier    | 61       | 68.9655   | 40     | 50.6329  | 0.604123      |
# | LightGBM              | 56       | 60.0000   | 36     | 45.0000  | 0.608483      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.646571      | {'C': 1, 'penalty': 'l2'}                        |
# | Decision Tree         | 60       | 66.6667   | 40     | 50       | 0.633083      | {'max_depth': 5, 'min_samples_split': 10}        |
# | Random Forest         | 62       | 71.4286   | 40     | 51.2821  | 0.641811      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 50}  |
# | SVM                   | 57       | 65.2174   | 30     | 41.0959  | 0.644987      | {'C': 0.1, 'kernel': 'rbf'}                      |
# | Gradient Boosting     | 60       | 67.8571   | 38     | 48.7179  | 0.643802      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 54       | 56.6667   | 34     | 42.5     | 0.642599      | {'alpha': 0.0001, 'hidden_layer_sizes': (100,)}  |
# | Voting Classifier     | 57       | 62.069    | 36     | 45.5696  | 0.642996      | {}                                               |
# | Bagging Classifier    | 60       | 69.2308   | 36     | 47.3684  | 0.632685      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.644987      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 62       | 73.0769   | 38     | 50       | 0.646576      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}    |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.56     | 0.538462  | 0.28   | 0.368421 | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.60     | 0.607143  | 0.34   | 0.435897 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.66     | 0.724138  | 0.42   | 0.531646 | {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5}                 |
# | SVM                   | 0.58     | 0.612903  | 0.38   | 0.469136 | {'C': 0.1, 'kernel': 'linear'}                                                  |
# | Gradient Boosting     | 0.61     | 0.558824  | 0.38   | 0.452381 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}                      |
# | Neural Network        | 0.55     | 0.472222  | 0.34   | 0.395349 | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                                  |
# | Voting Classifier     | 0.57     | 0.62069   | 0.36   | 0.455696 | {}                                                                               |
# | Bagging Classifier    | 0.63     | 0.666667  | 0.40   | 0.50     | {'n_estimators': 50, 'max_samples': 0.7}                                        |
# | XGBoost Classifier    | 0.65     | 0.5       | 0.36   | 0.418605 | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}                    |
# | LightGBM              | 0.64     | 0.575758  | 0.38   | 0.457831 | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}                    |

# %% [markdown]
# 2. 4
#
# purpose：label
# log：logVars
# std：standardization
# select：ridge (all)
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 53       | 55.5556   | 30     | 38.9610  | 0.648951      |
# | Decision Tree         | 51       | 51.2821   | 40     | 44.9438  | 0.557725      |
# | Random Forest         | 58       | 62.5000   | 40     | 48.7805  | 0.628325      |
# | SVM                   | 59       | 68.0000   | 34     | 45.3333  | 0.641012      |
# | Gradient Boosting     | 62       | 70.0000   | 42     | 52.5000  | 0.639433      |
# | Neural Network        | 53       | 54.5455   | 36     | 43.3735  | 0.633472      |
# | Voting Classifier     | 60       | 69.2308   | 36     | 47.3684  | 0.644580      |
# | Bagging Classifier    | 60       | 69.2308   | 36     | 47.3684  | 0.624360      |
# | XGBoost Classifier    | 57       | 62.0690   | 36     | 45.5696  | 0.606510      |
# | LightGBM              | 59       | 64.5161   | 40     | 49.3827  | 0.614842      |
#
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 53       | 55.5556   | 30     | 38.961   | 0.650538      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 60       | 66.6667   | 40     | 50       | 0.630312      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 62       | 73.0769   | 38     | 50       | 0.648945      | {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100} |
# | SVM                   | 56       | 63.6364   | 28     | 38.8889  | 0.64102       | {'C': 0.1, 'kernel': 'rbf'}                      |
# | Gradient Boosting     | 67       | 57.8571   | 38     | 48.7179  | 0.643795      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 50       | 50        | 26     | 34.2105  | 0.639421      | {'alpha': 0.01, 'hidden_layer_sizes': (50,)}     |
# | Voting Classifier     | 59       | 66.6667   | 36     | 46.7532  | 0.647756      | {}                                               |
# | Bagging Classifier    | 57       | 60.0061   | 40     | 48.1928  | 0.627133      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 60       | 67.8571   | 38     | 48.7179  | 0.641813      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 59       | 66.6667   | 36     | 46.7532  | 0.64578       | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.56     | 0.555556  | 0.30   | 0.38961  | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                              |
# | Decision Tree         | 0.60     | 0.571429  | 0.40   | 0.470588 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.63     | 0.689655  | 0.40   | 0.506329 | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5}                   |
# | SVM                   | 0.59     | 0.645161  | 0.40   | 0.493827 | {'C': 1, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting     | 0.63     | 0.580645  | 0.36   | 0.444444 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | Neural Network        | 0.56     | 0.548387  | 0.34   | 0.419753 | {'hidden_layer_sizes': (100,), 'alpha': 0.01}                                   |
# | Voting Classifier     | 0.59     | 0.666667  | 0.36   | 0.467532 | {}                                                                               |
# | Bagging Classifier    | 0.61     | 0.692308  | 0.36   | 0.473684 | {'n_estimators': 100, 'max_samples': 0.7}                                       |
# | XGBoost Classifier    | 0.62     | 0.586207  | 0.36   | 0.43038  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | LightGBM              | 0.65     | 0.62963   | 0.34   | 0.441558 | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5}                     |

# %% [markdown]
# ----------------

# %% [markdown]
# 3. 1
#
# purpose：label
# log：IQRVars
# std：min-max scaling
# select：forward：'int.rate', 'inq.last.6mths', 'days.with.cr.line', 'credit.policy'
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 58       | 63.3333   | 38     | 47.5     | 0.641019      |
# | Decision Tree         | 51       | 50.9804   | 52     | 51.4851  | 0.564858      |
# | Random Forest         | 50       | 50        | 48     | 48.9796  | 0.593032      |
# | SVM                   | 58       | 66.6667   | 32     | 43.2432  | 0.637452      |
# | Gradient Boosting     | 54       | 56.6667   | 34     | 42.5     | 0.622771      |
# | Neural Network        | 57       | 60.6061   | 40     | 48.1928  | 0.642209      |
# | Voting Classifier     | 60       | 66.6667   | 40     | 50       | 0.644193      |
# | Bagging Classifier    | 52       | 52.0833   | 50     | 51.0204  | 0.595011      |
# | XGBoost Classifier    | 59       | 60.4651   | 52     | 55.914   | 0.581121      |
# | LightGBM              | 56       | 58.8235   | 40     | 47.619   | 0.594612      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 58       | 63.3333   | 38     | 47.5     | 0.641019      | {'C': 1, 'penalty': 'l2'}                       |
# | Decision Tree         | 56       | 58.8235   | 40     | 47.619   | 0.642609      | {'max_depth': 5, 'min_samples_split': 10}       |
# | Random Forest         | 57       | 61.2903   | 38     | 46.9136  | 0.628326      | {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200} |
# | SVM                   | 58       | 66.6667   | 32     | 43.2432  | 0.637855      | {'C': 0.1, 'kernel': 'linear'}                  |
# | Gradient Boosting     | 57       | 62.963    | 34     | 44.1558  | 0.637445      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}    |
# | Neural Network        | 57       | 61.1111   | 44     | 51.1628  | 0.644192      | {'alpha': 0.0001, 'hidden_layer_sizes': (50, 50)}|
# | Voting Classifier     | 60       | 66.6667   | 40     | 50       | 0.647764      | {}                                               |
# | Bagging Classifier    | 54       | 55        | 44     | 48.8889  | 0.603744      | {'max_samples': 0.5, 'n_estimators': 50}        |
# | XGBoost Classifier    | 58       | 64.2857   | 36     | 46.1538  | 0.637446      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}    |
# | LightGBM              | 56       | 60        | 36     | 45       | 0.638637      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}    |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.58     | 0.612903  | 0.38   | 0.469136 | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                                |
# | Decision Tree         | 0.62     | 0.65625   | 0.42   | 0.512195 | {'max_depth': 10, 'min_samples_split': 2}                                       |
# | Random Forest         | 0.59     | 0.454545  | 0.40   | 0.425532 | {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 2}                  |
# | SVM                   | 0.58     | 0.653846  | 0.34   | 0.447368 | {'C': 0.1, 'kernel': 'linear'}                                                  |
# | Gradient Boosting     | 0.62     | 0.6       | 0.48   | 0.533333 | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 3}                        |
# | Neural Network        | 0.58     | 0.611111  | 0.44   | 0.511628 | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                                  |
# | Voting Classifier     | 0.61     | 0.689655  | 0.40   | 0.506329 | {}                                                                               |
# | Bagging Classifier    | 0.55     | 0.520833  | 0.50   | 0.510204 | {'n_estimators': 50, 'max_samples': 0.7}                                        |
# | XGBoost Classifier    | 0.63     | 0.571429  | 0.48   | 0.521739 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}                     |
# | LightGBM              | 0.62     | 0.547157  | 0.58   | 0.563107 | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}                       |

# %% [markdown]
# 3. 2
#
# purpose：label
# log：IQRVars
# std：min-max scaling
# select：lasso->'credit.policy', 'purpose', 'int.rate', 'fico', 'inq.last.6mths'
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 60       | 64.7059   | 44     | 52.381   | 0.643002      |
# | Decision Tree         | 53       | 53.1915   | 50     | 51.5464  | 0.577952      |
# | Random Forest         | 65       | 67.4419   | 58     | 62.3656  | 0.603341      |
# | SVM                   | 60       | 66.6667   | 40     | 50       | 0.649353      |
# | Gradient Boosting     | 59       | 63.6364   | 42     | 50.6024  | 0.644595      |
# | Neural Network        | 59       | 63.6364   | 42     | 50.6024  | 0.655298      |
# | Voting Classifier     | 62       | 70        | 42     | 52.5     | 0.648954      |
# | Bagging Classifier    | 62       | 65        | 52     | 57.7778  | 0.600163      |
# | XGBoost Classifier    | 61       | 64.8649   | 48     | 55.1724  | 0.614446      |
# | LightGBM              | 63       | 68.5714   | 48     | 56.4706  | 0.619993      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 60       | 65.625    | 42     | 51.2195  | 0.646568      | {'C': 0.1, 'penalty': 'l2'}                      |
# | Decision Tree         | 61       | 67.7419   | 42     | 51.8519  | 0.649353      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 64       | 73.3333   | 44     | 55       | 0.648949      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100} |
# | SVM                   | 63       | 74.0741   | 40     | 51.9481  | 0.650145      | {'C': 10, 'kernel': 'rbf'}                       |
# | Gradient Boosting     | 58       | 63.3333   | 38     | 47.5     | 0.649751      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
# | Neural Network        | 61       | 66.6667   | 44     | 53.012   | 0.656884      | {'alpha': 0.001, 'hidden_layer_sizes': (100,)}   |
# | Voting Classifier     | 61       | 67.7419   | 42     | 51.8519  | 0.651773      | {}                                               |
# | Bagging Classifier    | 56       | 57.8947   | 44     | 50       | 0.621985      | {'max_samples': 0.5, 'n_estimators': 50}         |
# | XGBoost Classifier    | 61       | 68.9655   | 40     | 50.6329  | 0.650939      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 63       | 69.697    | 46     | 55.4217  | 0.655704      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.60     | 0.647059  | 0.44   | 0.52381  | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                                |
# | Decision Tree         | 0.61     | 0.53125   | 0.34   | 0.414634 | {'max_depth': 5, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.66     | 0.560976  | 0.46   | 0.505495 | {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 2}                |
# | SVM                   | 0.63     | 0.740741  | 0.40   | 0.519481 | {'C': 10, 'kernel': 'rbf'}                                                      |
# | Gradient Boosting     | 0.63     | 0.666667  | 0.48   | 0.55814  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | Neural Network        | 0.63     | 0.724138  | 0.42   | 0.531646 | {'hidden_layer_sizes': (50, 50), 'alpha': 0.0001}                               |
# | Voting Classifier     | 0.61     | 0.666667  | 0.40   | 0.53812  | {}                                                                               |
# | Bagging Classifier    | 0.62     | 0.65      | 0.52   | 0.577778 | {'n_estimators': 10, 'max_samples': 0.5}                                        |
# | XGBoost Classifier    | 0.65     | 0.666667  | 0.52   | 0.58427  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | LightGBM              | 0.65     | 0.585366  | 0.48   | 0.527473 | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}                       |

# %% [markdown]
# 3. 3
#
# purpose：label
# log：IQRVars
# std：min-max scaling
# select：kbest10->'credit.policy', 'purpose', 'int.rate', 'installment', 'dti', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', 'pub.rec'
#
# - easy_model
#
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 55       | 57.5758   | 38     | 45.7831  | 0.644191      |
# | Decision Tree         | 54       | 54.1667   | 52     | 53.0612  | 0.559323      |
# | Random Forest         | 60       | 63.1579   | 48     | 54.5455  | 0.612456      |
# | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.646577      |
# | Gradient Boosting     | 54       | 55.5556   | 40     | 46.5116  | 0.638247      |
# | Neural Network        | 57       | 60.6061   | 40     | 48.1928  | 0.653318      |
# | Voting Classifier     | 57       | 60.0000   | 42     | 49.4118  | 0.645383      |
# | Bagging Classifier    | 58       | 59.5238   | 50     | 54.3478  | 0.610476      |
# | XGBoost Classifier    | 55       | 55.3191   | 52     | 53.6082  | 0.600156      |
# | LightGBM              | 63       | 65.8537   | 54     | 59.3407  | 0.613655      |
#
#
# - model_CVscore_maximum
#
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 54       | 55.8824   | 38     | 45.2381  | 0.644192      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 58       | 61.7647   | 42     | 50       | 0.629516      | {'max_depth': 5, 'min_samples_split': 10}        |
# | Random Forest         | 57       | 60        | 42     | 49.4118  | 0.646175      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200} |
# | SVM                   | 59       | 63.6364   | 42     | 50.6024  | 0.649355      | {'C': 10, 'kernel': 'rbf'}                       |
# | Gradient Boosting     | 58       | 62.5      | 40     | 48.7805  | 0.642211      | {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200}    |
# | Neural Network        | 57       | 60.6061   | 40     | 48.1928  | 0.653318      | {'alpha': 0.0001, 'hidden_layer_sizes': (100,)}  |
# | Voting Classifier     | 59       | 62.8571   | 44     | 51.7647  | 0.643396      | {}                                               |
# | Bagging Classifier    | 59       | 63.6364   | 42     | 50       | 0.630313      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 62       | 70        | 42     | 52.5     | 0.646972      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 62       | 65.7895   | 50     | 56.8182  | 0.647767      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.59     | 0.558824  | 0.38   | 0.452381 | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                               |
# | Decision Tree         | 0.58     | 0.571429  | 0.56   | 0.565657 | {'max_depth': None, 'min_samples_split': 5}                                      |
# | Random Forest         | 0.64     | 0.595238  | 0.50   | 0.543478 | {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 2}                    |
# | SVM                   | 0.61     | 0.636364  | 0.42   | 0.506024 | {'C': 1, 'kernel': 'rbf'}                                                        |
# | Gradient Boosting     | 0.69     | 0.60      | 0.54   | 0.568421 | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 7}                        |
# | Neural Network        | 0.58     | 0.588235  | 0.40   | 0.476190 | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                                   |
# | Voting Classifier     | 0.58     | 0.617647  | 0.42   | 0.500000 | {}                                                                               |
# | Bagging Classifier    | 0.62     | 0.595238  | 0.50   | 0.543478 | {'n_estimators': 50, 'max_samples': 1.0}                                         |
# | XGBoost Classifier    | 0.64     | 0.574468  | 0.54   | 0.556701 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7}                      |
# | LightGBM              | 0.66     | 0.652174  | 0.60   | 0.625000 | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7}                      |

# %% [markdown]
# 3. 4
#
# purpose：label
# log：IQRVars
# std：min-max scaling
# select：ridge (all)
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 51       | 51.8519   | 28     | 36.3636  | 0.647364      |
# | Decision Tree         | 57       | 58.1395   | 50     | 53.7634  | 0.556535      |
# | Random Forest         | 56       | 57.8947   | 44     | 50       | 0.627134      |
# | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.645782      |
# | Gradient Boosting     | 58       | 64.2857   | 36     | 46.1538  | 0.639037      |
# | Neural Network        | 50       | 50        | 26     | 34.2105  | 0.646178      |
# | Voting Classifier     | 58       | 62.5      | 40     | 48.7805  | 0.646179      |
# | Bagging Classifier    | 62       | 65.7895   | 50     | 56.8182  | 0.625549      |
# | XGBoost Classifier    | 56       | 57.5      | 46     | 51.1111  | 0.60651       |
# | LightGBM              | 54       | 55.5556   | 40     | 46.5116  | 0.616423      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 51       | 51.8519   | 28     | 36.3636  | 0.649348      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 58       | 61.7647   | 42     | 50       | 0.629916      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 58       | 61.1111   | 44     | 51.1628  | 0.650135      | {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100} |
# | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.645782      | {'C': 1, 'kernel': 'rbf'}                        |
# | Gradient Boosting     | 62       | 71.4286   | 40     | 51.2821  | 0.644191      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 54       | 57.1429   | 32     | 41.0256  | 0.64522       | {'alpha': 0.001, 'hidden_layer_sizes': (50,)}    |
# | Voting Classifier     | 57       | 61.2903   | 38     | 46.9136  | 0.645379      | {}                                               |
# | Bagging Classifier    | 63       | 67.5676   | 50     | 57.4713  | 0.628722      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 62       | 70        | 42     | 52.5     | 0.641813      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 61       | 68.9655   | 40     | 50.6329  | 0.643003      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.59     | 0.518519  | 0.28   | 0.363636 | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                               |
# | Decision Tree         | 0.58     | 0.571429  | 0.48   | 0.521739 | {'max_depth': 5, 'min_samples_split': 2}                                         |
# | Random Forest         | 0.61     | 0.628571  | 0.44   | 0.517647 | {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 10}                 |
# | SVM                   | 0.61     | 0.645161  | 0.40   | 0.493827 | {'C': 1, 'kernel': 'rbf'}                                                        |
# | Gradient Boosting     | 0.66     | 0.628571  | 0.44   | 0.517647 | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5}                     |
# | Neural Network        | 0.55     | 0.606061  | 0.22   | 0.314286 | {'hidden_layer_sizes': (50,), 'alpha': 0.01}                                     |
# | Voting Classifier     | 0.57     | 0.606061  | 0.40   | 0.481928 | {}                                                                               |
# | Bagging Classifier    | 0.66     | 0.657895  | 0.50   | 0.568182 | {'n_estimators': 50, 'max_samples': 1.0}                                         |
# | XGBoost Classifier    | 0.66     | 0.636364  | 0.56   | 0.595745 | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | LightGBM              | 0.65     | 0.692308  | 0.54   | 0.606742 | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7}                      |

# %% [markdown]
# -------------------

# %% [markdown]
# 4. 1
#
# purpose：label
# log：logVars
# std：min-max scaling
# select：forward：'int.rate', 'inq.last.6mths', 'days.with.cr.line', 'credit.policy'
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 58       | 63.3333   | 38     | 47.5     | 0.640622      |
# | Decision Tree         | 51       | 51.0204   | 50     | 50.5051  | 0.564858      |
# | Random Forest         | 50       | 50        | 48     | 48.9796  | 0.593429      |
# | SVM                   | 58       | 66.6667   | 32     | 43.2432  | 0.637452      |
# | Gradient Boosting     | 55       | 58.6207   | 34     | 43.0838  | 0.622771      |
# | Neural Network        | 57       | 60.6061   | 40     | 48.1928  | 0.643092      |
# | Voting Classifier     | 60       | 67.8571   | 38     | 48.7179  | 0.646178      |
# | Bagging Classifier    | 51       | 51.1111   | 46     | 48.4211  | 0.594615      |
# | XGBoost Classifier    | 55       | 56.4103   | 44     | 49.4382  | 0.581121      |
# | LightGBM              | 53       | 54.0541   | 40     | 45.977   | 0.594612      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 58       | 63.3333   | 38     | 47.5     | 0.641416      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 57       | 60.6061   | 40     | 48.1928  | 0.642609      | {'max_depth': 5, 'min_samples_split': 10}        |
# | Random Forest         | 57       | 61.2903   | 38     | 46.9136  | 0.628326      | {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200} |
# | SVM                   | 58       | 66.6667   | 32     | 43.2432  | 0.63785       | {'C': 0.1, 'kernel': 'linear'}                   |
# | Gradient Boosting     | 58       | 65.3846   | 34     | 44.7368  | 0.637445      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
# | Neural Network        | 58       | 61.1111   | 44     | 51.1628  | 0.645779      | {'alpha': 0.01, 'hidden_layer_sizes': (50, 50)}  |
# | Voting Classifier     | 61       | 68.9655   | 40     | 50.6329  | 0.646575      | {}                                               |
# | Bagging Classifier    | 55       | 56.7568   | 42     | 48.2759  | 0.602948      | {'max_samples': 0.5, 'n_estimators': 50}         |
# | XGBoost Classifier    | 58       | 64.2857   | 36     | 46.1538  | 0.637446      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
# | LightGBM              | 56       | 60        | 36     | 45       | 0.638637      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.58     | 0.633333  | 0.38   | 0.475    | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                                 |
# | Decision Tree         | 0.61     | 0.65625   | 0.42   | 0.512195 | {'max_depth': 10, 'min_samples_split': 2}                                        |
# | Random Forest         | 0.58     | 0.475     | 0.38   | 0.422222 | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5}                    |
# | SVM                   | 0.58     | 0.653846  | 0.34   | 0.447368 | {'C': 0.1, 'kernel': 'linear'}                                                   |
# | Gradient Boosting     | 0.62     | 0.583566  | 0.48   | 0.527473 | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 3}                         |
# | Neural Network        | 0.58     | 0.611111  | 0.44   | 0.511628 | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                                   |
# | Voting Classifier     | 0.60     | 0.678571  | 0.38   | 0.487179 | {}                                                                               |
# | Bagging Classifier    | 0.57     | 0.511111  | 0.46   | 0.484211 | {'n_estimators': 50, 'max_samples': 0.7}                                         |
# | XGBoost Classifier    | 0.62     | 0.536585  | 0.44   | 0.483516 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}                      |
# | LightGBM              | 0.60     | 0.530612  | 0.52   | 0.525253 | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}                        |

# %% [markdown]
# 4. 2
#
# purpose：label
# log：logVars
# std：min-max scaling
# select：lasso：'credit.policy', 'purpose', 'int.rate', 'fico', 'inq.last.6mths'
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 60       | 64.7059   | 44     | 52.381   | 0.643399      |
# | Decision Tree         | 57       | 58.5366   | 48     | 52.7473  | 0.579536      |
# | Random Forest         | 65       | 68.2927   | 56     | 61.5385  | 0.603736      |
# | SVM                   | 60       | 66.6667   | 40     | 50       | 0.649749      |
# | Gradient Boosting     | 59       | 63.6364   | 42     | 50.6024  | 0.644595      |
# | Neural Network        | 61       | 66.6667   | 44     | 53.012   | 0.653709      |
# | Voting Classifier     | 61       | 67.7419   | 42     | 51.8519  | 0.649348      |
# | Bagging Classifier    | 63       | 66.6667   | 52     | 58.427   | 0.602939      |
# | XGBoost Classifier    | 57       | 59.4595   | 44     | 50.5747  | 0.614446      |
# | LightGBM              | 66       | 72.2222   | 52     | 60.4651  | 0.619993      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 60       | 65.625    | 42     | 51.2195  | 0.64498       | {'C': 0.1, 'penalty': 'l2'}                      |
# | Decision Tree         | 61       | 67.7419   | 42     | 51.8519  | 0.649749      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 61       | 67.7419   | 42     | 51.8519  | 0.648553      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100} |
# | SVM                   | 62       | 71.4286   | 40     | 51.2821  | 0.650541      | {'C': 10, 'kernel': 'rbf'}                       |
# | Gradient Boosting     | 58       | 63.3333   | 38     | 47.5     | 0.649751      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
# | Neural Network        | 63       | 72.4138   | 42     | 53.1646  | 0.657678      | {'alpha': 0.0001, 'hidden_layer_sizes': (50, 50)} |
# | Voting Classifier     | 61       | 67.7419   | 42     | 51.8519  | 0.652292      | {}                                               |
# | Bagging Classifier    | 63       | 68.5714   | 48     | 56.4706  | 0.61881       | {'max_samples': 0.5, 'n_estimators': 50}         |
# | XGBoost Classifier    | 61       | 68.9655   | 40     | 50.6329  | 0.650939      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 63       | 69.697    | 46     | 55.4217  | 0.655704      | {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}      |
#
# - model_accuracy_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |-----------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression   | 0.60     | 0.647059  | 0.44   | 0.52381  | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                               |
# | Decision Tree         | 0.61     | 0.548387  | 0.34   | 0.419753 | {'max_depth': 5, 'min_samples_split': 2}                                         |
# | Random Forest         | 0.67     | 0.611111  | 0.44   | 0.511628 | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 2}                   |
# | SVM                   | 0.62     | 0.714286  | 0.40   | 0.512821 | {'C': 10, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting     | 0.66     | 0.619048  | 0.52   | 0.565217 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7}                      |
# | Neural Network        | 0.63     | 0.724138  | 0.42   | 0.531646 | {'hidden_layer_sizes': (50, 50), 'alpha': 0.0001}                                |
# | Voting Classifier     | 0.61     | 0.689655  | 0.40   | 0.506329 | {}                                                                               |
# | Bagging Classifier    | 0.66     | 0.666667  | 0.52   | 0.58427  | {'n_estimators': 100, 'max_samples': 0.5}                                        |
# | XGBoost Classifier    | 0.64     | 0.571429  | 0.48   | 0.521739 | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}                     |
# | LightGBM              | 0.65     | 0.60      | 0.54   | 0.568421 | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}                        |

# %% [markdown]
# 4. 3
#
# purpose：label
# log：logVars
# std：min-max scaling
# select：kbest10->'credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', 'pub.rec'
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 53       | 55.5556   | 30     | 38.9610  | 0.641018      |
# | Decision Tree         | 54       | 54.7619   | 46     | 50.0000  | 0.557314      |
# | Random Forest         | 57       | 58.5366   | 48     | 52.7473  | 0.629121      |
# | SVM                   | 60       | 66.6667   | 40     | 50.0000  | 0.648559      |
# | Gradient Boosting     | 55       | 57.5758   | 38     | 45.7831  | 0.637839      |
# | Neural Network        | 55       | 60.0000   | 30     | 40.0000  | 0.651726      |
# | Voting Classifier     | 60       | 65.6250   | 42     | 51.2195  | 0.647764      |
# | Bagging Classifier    | 58       | 61.7647   | 42     | 50.0000  | 0.614436      |
# | XGBoost Classifier    | 54       | 54.5455   | 48     | 51.0638  | 0.604123      |
# | LightGBM              | 56       | 57.8947   | 44     | 50.0000  | 0.611266      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.647364      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 58       | 61.7647   | 42     | 50       | 0.635464      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 56       | 58.8235   | 40     | 47.619   | 0.645777      | {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100} |
# | SVM                   | 60       | 66.6667   | 40     | 50       | 0.648559      | {'C': 1, 'kernel': 'rbf'}                        |
# | Gradient Boosting     | 60       | 66.6667   | 40     | 50       | 0.643802      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 53       | 56        | 28     | 37.3333  | 0.658866      | {'alpha': 0.0001, 'hidden_layer_sizes': (50,)}   |
# | Voting Classifier     | 58       | 61.7647   | 42     | 50       | 0.646174      | {}                                               |
# | Bagging Classifier    | 58       | 61.7647   | 42     | 50       | 0.628726      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 61       | 68.9655   | 40     | 50.6329  | 0.644987      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 62       | 70        | 42     | 52.5     | 0.646176      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
#
# - model_accuracy_maximum
#
# | Model               | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |---------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression | 0.60     | 0.647059  | 0.44   | 0.52381  | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                               |
# | Decision Tree       | 0.61     | 0.548387  | 0.34   | 0.419753 | {'max_depth': 5, 'min_samples_split': 2}                                         |
# | Random Forest       | 0.67     | 0.611111  | 0.44   | 0.511628 | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 2}                   |
# | SVM                 | 0.62     | 0.714286  | 0.40   | 0.512821 | {'C': 10, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting   | 0.66     | 0.619048  | 0.52   | 0.565217 | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7}                      |
# | Neural Network      | 0.63     | 0.724138  | 0.42   | 0.531646 | {'hidden_layer_sizes': (50, 50), 'alpha': 0.0001}                                |
# | Voting Classifier   | 0.62     | 0.65625   | 0.42   | 0.512195 | {}                                                                               |
# | Bagging Classifier  | 0.66     | 0.666667  | 0.52   | 0.58427  | {'n_estimators': 100, 'max_samples': 0.5}                                        |
# | XGBoost Classifier  | 0.64     | 0.571429  | 0.48   | 0.521739 | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}                     |
# | LightGBM            | 0.65     | 0.6       | 0.54   | 0.568421 | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}                        |

# %% [markdown]
# 4. 4
#
# purpose：label
# log：logVars
# std：min-max scaling
# select：ridge(all)
#
#
# - easy_model
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |-----------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.647364      |
# | Decision Tree         | 55       | 55.814    | 48     | 51.6129  | 0.557725      |
# | Random Forest         | 59       | 61.5385   | 48     | 53.9326  | 0.628325      |
# | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.646178      |
# | Gradient Boosting     | 57       | 62.069    | 36     | 45.5696  | 0.639433      |
# | Neural Network        | 51       | 51.8519   | 28     | 36.3636  | 0.643789      |
# | Voting Classifier     | 60       | 65.625    | 42     | 51.2195  | 0.647366      |
# | Bagging Classifier    | 64       | 67.5      | 54     | 60       | 0.62436       |
# | XGBoost Classifier    | 54       | 55        | 44     | 48.8889  | 0.60651       |
# | LightGBM              | 55       | 56.7568   | 42     | 48.2759  | 0.616424      |
#
# - model_CVscore_maximum
#
# | Model                 | Accuracy | Precision | Recall | F1-score | Mean CV Score | Best Parameters                                  |
# |-----------------------|----------|-----------|--------|----------|---------------|--------------------------------------------------|
# | Logistic Regression   | 52       | 53.8462   | 28     | 36.8421  | 0.650538      | {'C': 10, 'penalty': 'l2'}                       |
# | Decision Tree         | 58       | 61.7647   | 42     | 50       | 0.630312      | {'max_depth': 5, 'min_samples_split': 2}         |
# | Random Forest         | 58       | 61.1111   | 44     | 51.1628  | 0.648945      | {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100} |
# | SVM                   | 61       | 68.9655   | 40     | 50.6329  | 0.646178      | {'C': 1, 'kernel': 'rbf'}                        |
# | Gradient Boosting     | 62       | 71.4286   | 40     | 51.2821  | 0.643795      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | Neural Network        | 56       | 60        | 36     | 45       | 0.652112      | {'alpha': 0.01, 'hidden_layer_sizes': (50,)}     |
# | Voting Classifier     | 59       | 64.5161   | 40     | 49.3827  | 0.649745      | {}                                               |
# | Bagging Classifier    | 63       | 68.5714   | 48     | 56.4706  | 0.627133      | {'max_samples': 0.5, 'n_estimators': 100}        |
# | XGBoost Classifier    | 62       | 70        | 42     | 52.5     | 0.641813      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
# | LightGBM              | 61       | 68.9655   | 40     | 50.6329  | 0.643003      | {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}    |
#
# - model_accuracy_maximum
#
# | Model               | Accuracy | Precision | Recall | F1-score | Best Parameters                                                                  |
# |---------------------|----------|-----------|--------|----------|----------------------------------------------------------------------------------|
# | Logistic Regression | 0.59     | 0.538462  | 0.28   | 0.368421 | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                               |
# | Decision Tree       | 0.58     | 0.545455  | 0.48   | 0.510638 | {'max_depth': 5, 'min_samples_split': 2}                                         |
# | Random Forest       | 0.61     | 0.628571  | 0.44   | 0.517647 | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 10}                  |
# | SVM                 | 0.61     | 0.645161  | 0.4    | 0.493827 | {'C': 1, 'kernel': 'rbf'}                                                       |
# | Gradient Boosting   | 0.66     | 0.65263   | 0.46   | 0.522727 | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5}                     |
# | Neural Network      | 0.56     | 0.611111  | 0.22   | 0.323529 | {'hidden_layer_sizes': (50,), 'alpha': 0.001}                                    |
# | Voting Classifier   | 0.6      | 0.65625   | 0.42   | 0.512195 | {}                                                                               |
# | Bagging Classifier  | 0.67     | 0.675     | 0.54   | 0.6       | {'n_estimators': 50, 'max_samples': 1.0}                                         |
# | XGBoost Classifier  | 0.64     | 0.586957  | 0.48   | 0.5625   | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}                     |
# | LightGBM            | 0.64     | 0.675     | 0.54   | 0.6       | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 5}                        |

# %% [markdown]
# -----

# %% [markdown]
# 5. 1
#
# purpose：dummy
# log：IQRVars
# std：standardization
# select：forward  ->  'inq.last.6mths', 'credit.policy',  'fico', 'purpose_major_purchase', 'purpose_credit_card', 'purpose_educational', 'purpose_debt_consolidation'
#
#
# - easy_model
#
# | Model               | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |---------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression | 60       | 72.7273   | 32     | 44.4444  | 0.645773      |
# | Decision Tree       | 52       | 53.5714   | 30     | 38.4615  | 0.595394      |
# | Random Forest       | 53       | 54.2857   | 38     | 44.7059  | 0.594201      |
# | SVM                 | 59       | 69.5652   | 32     | 43.8356  | 0.643801      |
# | Gradient Boosting   | 60       | 75.0000   | 30     | 42.8571  | 0.639033      |
# | Neural Network      | 58       | 68.1818   | 30     | 41.6667  | 0.649350      |
# | Voting Classifier   | 62       | 77.2727   | 34     | 47.2222  | 0.644587      |
# | Bagging Classifier  | 54       | 55.8824   | 38     | 45.2381  | 0.596187      |
# | XGBoost Classifier  | 53       | 56.5217   | 26     | 35.6164  | 0.601741      |
# | LightGBM            | 55       | 59.2593   | 32     | 41.5584  | 0.614837      |
#
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model               | Accuracy | Precision | Recall | F1-score | Best Parameters                              |
# |---------------------|----------|-----------|--------|----------|----------------------------------------------|
# | Logistic Regression | 0.6      | 0.727273  | 0.32   | 0.444444 | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'} |
# | Decision Tree       | 0.57     | 0.565217  | 0.26   | 0.356164 | {'max_depth': 5, 'min_samples_split': 2}     |
# | Random Forest       | 0.58     | 0.580645  | 0.36   | 0.444444 | {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5} |
# | SVM                 | 0.6      | 0.727273  | 0.32   | 0.444444 | {'C': 100, 'kernel': 'poly'}                 |
# | Gradient Boosting   | 0.6      | 0.5       | 0.36   | 0.418605 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}      |
# | Neural Network      | 0.61     | 0.684211  | 0.26   | 0.376812 | {'hidden_layer_sizes': (50,), 'alpha': 0.1}  |
# | Voting Classifier   | 0.61     | 0.73913   | 0.34   | 0.465753 | {}                                           |
# | Bagging Classifier  | 0.56     | 0.529412  | 0.36   | 0.428571 | {'n_estimators': 10, 'max_samples': 0.7}     |
# | XGBoost Classifier  | 0.58     | 0.517241  | 0.36   | 0.379747 | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}      |
# | LightGBM            | 0.6      | 0.5625    | 0.36   | 0.439024 | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 3}    |

# %% [markdown]
# 5. 2
# purpose：dummy
# log：IQRVars
# std：standardization
# select：lasso  ->  'credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'fico', 'inq.last.6mths', 'purpose_credit_card', 'purpose_small_business'
#
# - easy_model
#
# | Model               | Accuracy | Precision | Recall | F1-score | Mean CV Score |
# |---------------------|----------|-----------|--------|----------|---------------|
# | Logistic Regression | 61       | 70.3704   | 38     | 49.3506  | 0.653771      |
# | Decision Tree       | 52       | 52.0833   | 50     | 51.0204  | 0.5589        |
# | Random Forest       | 61       | 68.9655   | 40     | 50.6329  | 0.600165      |
# | SVM                 | 61       | 68.9655   | 40     | 50.6329  | 0.645878      |
# | Gradient Boosting   | 61       | 68.9655   | 40     | 50.6329  | 0.631896      |
# | Neural Network      | 61       | 67.7419   | 42     | 51.8519  | 0.640227      |
# | Voting Classifier   | 62       | 71.4286   | 40     | 51.2821  | 0.646968      |
# | Bagging Classifier  | 61       | 68.9655   | 40     | 50.6329  | 0.597778      |
# | XGBoost Classifier  | 65       | 71.4286   | 46     | 54.1176  | 0.581114      |
# | LightGBM            | 62       | 68.75     | 44     | 53.6585  | 0.608884      |
#
# - model_CVscore_maximum
#
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision   | Recall | F1-score   | Best Parameters                                                      |
# |----------------------|----------|-------------|--------|------------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.61     | 0.703704    | 0.38   | 0.493506   | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                     |
# | Decision Tree        | 0.63     | 0.571429    | 0.48   | 0.521739   | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.65     | 0.7         | 0.42   | 0.525      | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 10}      |
# | SVM                  | 0.62     | 0.703704    | 0.38   | 0.493506   | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.64     | 0.580645    | 0.36   | 0.444444   | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 9}             |
# | Neural Network       | 0.61     | 0.653846    | 0.34   | 0.447368   | {'hidden_layer_sizes': (100,), 'alpha': 0.0001}                      |
# | Voting Classifier    | 0.62     | 0.7         | 0.42   | 0.525      | {}                                                                    |
# | Bagging Classifier   | 0.63     | 0.655172    | 0.4    | 0.481013   | {'n_estimators': 100, 'max_samples': 0.7}                            |
# | XGBoost Classifier   | 0.62     | 0.621622    | 0.46   | 0.528736   | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3}         |
# | LightGBM             | 0.67     | 0.53125     | 0.34   | 0.414634   | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 9}          |

# %% [markdown]
# 5. 3
# purpose：dummy
# log：IQRVars
# std：standardization
# select：kbest12  ->  'credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', 'pub.rec', 'purpose_credit_card', 'purpose_small_business'
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 56       | 60         | 36     | 45        | 0.650144      |
# | Decision Tree        | 54       | 54         | 54     | 54        | 0.562874      |
# | Random Forest        | 59       | 62.8571    | 44     | 51.7647   | 0.619598      |
# | SVM                  | 59       | 66.6667    | 36     | 46.7532   | 0.639036      |
# | Gradient Boosting    | 61       | 67.7419    | 42     | 51.8519   | 0.629513      |
# | Neural Network       | 58       | 63.3333    | 38     | 47.5      | 0.637049      |
# | Voting Classifier    | 58       | 64.2857    | 36     | 46.1538   | 0.645777      |
# | Bagging Classifier   | 57       | 61.2903    | 38     | 46.9136   | 0.616828      |
# | XGBoost Classifier   | 60       | 63.8889    | 46     | 53.4884   | 0.593017      |
# | LightGBM             | 60       | 63.1579    | 48     | 54.5455   | 0.601748      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.58     | 0.6        | 0.36   | 0.45      | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.62     | 0.461538   | 0.36   | 0.404494  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.64     | 0.65625    | 0.42   | 0.512195  | {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 2}       |
# | SVM                  | 0.61     | 0.666667   | 0.28   | 0.393466  | {'C': 0.1, 'kernel': 'linear'}                                       |
# | Gradient Boosting    | 0.64     | 0.648649   | 0.48   | 0.551724  | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7}          |
# | Neural Network       | 0.58     | 0.487179   | 0.38   | 0.426966  | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                       |
# | Voting Classifier    | 0.58     | 0.642857   | 0.36   | 0.461538  | {}                                                                    |
# | Bagging Classifier   | 0.61     | 0.645161   | 0.4    | 0.493827  | {'n_estimators': 10, 'max_samples': 0.5}                             |
# | XGBoost Classifier   | 0.65     | 0.552632   | 0.42   | 0.477273  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}           |
# | LightGBM             | 0.66     | 0.621622   | 0.46   | 0.528736  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 9}             |

# %% [markdown]
# 5. 4
#
# purpose：dummy
# log：IQRVars
# std：standardization
# select：ridge (all)
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 61       | 68.9655    | 40     | 50.6329   | 0.654499      |
# | Decision Tree        | 59       | 60.9756    | 50     | 54.9451   | 0.558516      |
# | Random Forest        | 61       | 68.9655    | 40     | 50.6329   | 0.62237       |
# | SVM                  | 61       | 72         | 36     | 48        | 0.648553      |
# | Gradient Boosting    | 63       | 72.4138    | 42     | 53.1646   | 0.638243      |
# | Neural Network       | 59       | 63.6364    | 42     | 50.6024   | 0.636254      |
# | Voting Classifier    | 62       | 73.0769    | 38     | 50        | 0.652123      |
# | Bagging Classifier   | 64       | 75         | 42     | 53.8462   | 0.621979      |
# | XGBoost Classifier   | 59       | 62.8571    | 44     | 51.7647   | 0.608489      |
# | LightGBM             | 60       | 65.625     | 42     | 51.2195   | 0.615634      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.62     | 0.7        | 0.42   | 0.525     | {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.62     | 0.571429   | 0.4    | 0.470588  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.65     | 0.7        | 0.42   | 0.525     | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 10}      |
# | SVM                  | 0.63     | 0.708333   | 0.34   | 0.459459  | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.65     | 0.566667   | 0.34   | 0.425     | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 9}          |
# | Neural Network       | 0.61     | 0.615385   | 0.48   | 0.539326  | {'hidden_layer_sizes': (100,), 'alpha': 0.01}                        |
# | Voting Classifier    | 0.62     | 0.730769   | 0.38   | 0.5       | {}                                                                    |
# | Bagging Classifier   | 0.65     | 0.777778   | 0.42   | 0.545455  | {'n_estimators': 200, 'max_samples': 1.0}                            |
# | XGBoost Classifier   | 0.67     | 0.594595   | 0.44   | 0.505747  | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7}         |
# | LightGBM             | 0.65     | 0.621622   | 0.46   | 0.528736  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 9}         |

# %% [markdown]
# ----------

# %% [markdown]
# 6. 1
#
# purpose：dummy
# log：logVars
# std：standardization
# select：forward  -> 'inq.last.6mths', 'credit.policy',  'fico', 'purpose_major_purchase', 'purpose_credit_card', 'purpose_educational', 'purpose_debt_consolidation'
#
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 60       | 72.7273    | 32     | 44.4444   | 0.646169      |
# | Decision Tree        | 52       | 53.5714    | 30     | 38.4615   | 0.594204      |
# | Random Forest        | 53       | 54.2857    | 38     | 44.7059   | 0.589045      |
# | SVM                  | 59       | 69.5652    | 32     | 43.8356   | 0.643007      |
# | Gradient Boosting    | 60       | 75         | 30     | 42.8571   | 0.639833      |
# | Neural Network       | 58       | 68.1818    | 30     | 41.6667   | 0.649747      |
# | Voting Classifier    | 62       | 77.2727    | 34     | 47.2222   | 0.644191      |
# | Bagging Classifier   | 54       | 55.8824    | 38     | 45.2381   | 0.594998      |
# | XGBoost Classifier   | 53       | 56.5217    | 26     | 35.6164   | 0.601741      |
# | LightGBM             | 55       | 59.2593    | 32     | 41.5584   | 0.614837      |
#
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.6      | 0.727273   | 0.32   | 0.444444  | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                     |
# | Decision Tree        | 0.57     | 0.565217   | 0.26   | 0.356164  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.58     | 0.580645   | 0.36   | 0.444444  | {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5}      |
# | SVM                  | 0.6      | 0.727273   | 0.32   | 0.444444  | {'C': 100, 'kernel': 'poly'}                                         |
# | Gradient Boosting    | 0.6      | 0.5        | 0.36   | 0.418605  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}           |
# | Neural Network       | 0.6      | 0.684211   | 0.26   | 0.376812  | {'hidden_layer_sizes': (50,), 'alpha': 0.0001}                       |
# | Voting Classifier    | 0.61     | 0.761905   | 0.32   | 0.450704  | {}                                                                    |
# | Bagging Classifier   | 0.56     | 0.529412   | 0.36   | 0.428571  | {'n_estimators': 10, 'max_samples': 0.7}                             |
# | XGBoost Classifier   | 0.6      | 0.517241   | 0.36   | 0.379747  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}           |
# | LightGBM             | 0.6      | 0.5625     | 0.36   | 0.439024  | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 3}         |

# %% [markdown]
# 6. 2
#
# purpose：dummy
# log：logVars
# std：standardization
# select：lasso  ->   'credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'fico', 'inq.last.6mths', 'purpose_credit_card', 'purpose_small_business'
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 61       | 70.3704    | 38     | 49.3506   | 0.653314      |
# | Decision Tree        | 52       | 52.0833    | 50     | 51.0204   | 0.559297      |
# | Random Forest        | 61       | 68.9655    | 40     | 50.6329   | 0.602148      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.643795      |
# | Gradient Boosting    | 61       | 68.9655    | 40     | 50.6329   | 0.6315        |
# | Neural Network       | 58       | 63.3333    | 38     | 47.5      | 0.637449      |
# | Voting Classifier    | 61       | 68.9655    | 40     | 50.6329   | 0.644191      |
# | Bagging Classifier   | 61       | 68.9655    | 40     | 50.6329   | 0.596194      |
# | XGBoost Classifier   | 61       | 65.7143    | 46     | 54.1176   | 0.581114      |
# | LightGBM             | 62       | 68.75      | 44     | 53.6585   | 0.608884      |
#
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.61     | 0.703704   | 0.38   | 0.493506  | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                     |
# | Decision Tree        | 0.6      | 0.571429   | 0.48   | 0.521739  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.65     | 0.7        | 0.42   | 0.525     | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 10}      |
# | SVM                  | 0.62     | 0.703704   | 0.38   | 0.493506  | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.64     | 0.548387   | 0.34   | 0.419753  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 9}             |
# | Neural Network       | 0.6      | 0.68       | 0.34   | 0.453333  | {'hidden_layer_sizes': (50, 50), 'alpha': 0.01}                      |
# | Voting Classifier    | 0.62     | 0.7        | 0.42   | 0.525     | {}                                                                    |
# | Bagging Classifier   | 0.62     | 0.655172   | 0.38   | 0.481013  | {'n_estimators': 100, 'max_samples': 0.5}                            |
# | XGBoost Classifier   | 0.64     | 0.621622   | 0.46   | 0.528736  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3}         |
# | LightGBM             | 0.67     | 0.53125    | 0.34   | 0.414634  | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 9}          |

# %% [markdown]
# 6. 3
#
# purpose：dummy
# log：logVars
# std：standardization
# select：kbest12  ->  'credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', 'pub.rec', 'purpose_credit_card', 'purpose_small_business'
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 56       | 60         | 36     | 45        | 0.65252       |
# | Decision Tree        | 50       | 50         | 52     | 50.9804   | 0.561289      |
# | Random Forest        | 57       | 60         | 42     | 49.4118   | 0.619596      |
# | SVM                  | 60       | 69.2308    | 36     | 47.3684   | 0.638241      |
# | Gradient Boosting    | 61       | 67.7419    | 42     | 51.8519   | 0.62991       |
# | Neural Network       | 58       | 63.3333    | 38     | 47.5      | 0.637849      |
# | Voting Classifier    | 58       | 64.2857    | 36     | 46.1538   | 0.644586      |
# | Bagging Classifier   | 58       | 62.5       | 40     | 48.7805   | 0.616826      |
# | XGBoost Classifier   | 61       | 65.7143    | 46     | 54.1176   | 0.593017      |
# | LightGBM             | 58       | 62.5       | 40     | 48.7805   | 0.605716      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.57     | 0.6        | 0.36   | 0.45      | {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}                  |
# | Decision Tree        | 0.62     | 0.45       | 0.36   | 0.4       | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.64     | 0.65625    | 0.42   | 0.512195  | {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 2}       |
# | SVM                  | 0.62     | 0.631579   | 0.24   | 0.347826  | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.62     | 0.657895   | 0.5    | 0.568182  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 9}             |
# | Neural Network       | 0.59     | 0.540541   | 0.4    | 0.45977   | {'hidden_layer_sizes': (100,), 'alpha': 0.01}                        |
# | Voting Classifier    | 0.58     | 0.642857   | 0.36   | 0.461538  | {}                                                                    |
# | Bagging Classifier   | 0.62     | 0.636364   | 0.42   | 0.506024  | {'n_estimators': 10, 'max_samples': 0.5}                             |
# | XGBoost Classifier   | 0.65     | 0.59375    | 0.38   | 0.463415  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}           |
# | LightGBM             | 0.64     | 0.675676   | 0.5    | 0.574713  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5}           |

# %% [markdown]
# 6. 4
#
# purpose：dummy
# log：logVars
# std：standardization
# select：ridge (all)
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 60       | 66.6667    | 40     | 50        | 0.658071      |
# | Decision Tree        | 58       | 60         | 48     | 53.3333   | 0.558119      |
# | Random Forest        | 61       | 68.9655    | 40     | 50.6329   | 0.625147      |
# | SVM                  | 61       | 72         | 36     | 48        | 0.650536      |
# | Gradient Boosting    | 63       | 72.4138    | 42     | 53.1646   | 0.63864       |
# | Neural Network       | 56       | 58.3333    | 42     | 48.8372   | 0.628324      |
# | Voting Classifier    | 62       | 73.0769    | 38     | 50        | 0.653311      |
# | Bagging Classifier   | 63       | 74.0741    | 40     | 51.9481   | 0.621979      |
# | XGBoost Classifier   | 57       | 60         | 42     | 49.4118   | 0.608489      |
# | LightGBM             | 59       | 63.6364    | 42     | 50.6024   | 0.603329      |
#
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.61     | 0.666667   | 0.4    | 0.5       | {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                     |
# | Decision Tree        | 0.62     | 0.583333   | 0.42   | 0.488372  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.65     | 0.7        | 0.42   | 0.525     | {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 10}      |
# | SVM                  | 0.62     | 0.72       | 0.36   | 0.48      | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.63     | 0.580645   | 0.36   | 0.444444  | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3}          |
# | Neural Network       | 0.58     | 0.589744   | 0.46   | 0.516854  | {'hidden_layer_sizes': (100,), 'alpha': 0.001}                       |
# | Voting Classifier    | 0.62     | 0.730769   | 0.38   | 0.5       | {}                                                                    |
# | Bagging Classifier   | 0.65     | 0.777778   | 0.42   | 0.545455  | {'n_estimators': 200, 'max_samples': 1.0}                            |
# | XGBoost Classifier   | 0.66     | 0.621622   | 0.46   | 0.528736  | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7}         |
# | LightGBM             | 0.65     | 0.5625     | 0.36   | 0.439024  | {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7}         |

# %% [markdown]
# ----------

# %% [markdown]
# 7. 1
#
# purpose：dummy
# log：IQRVars
# std：min-max scaling
# select：forward -> 'int.rate', 'inq.last.6mths','purpose_small_business','days.with.cr.line','credit.policy','purpose_credit_card'
#
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 61       | 68.9655    | 40     | 50.6329   | 0.65054       |
# | Decision Tree        | 48       | 48         | 48     | 48         | 0.566447      |
# | Random Forest        | 50       | 50         | 48     | 48.9796   | 0.600968      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.647764      |
# | Gradient Boosting    | 62       | 70         | 42     | 52.5      | 0.640226      |
# | Neural Network       | 60       | 65.625     | 42     | 51.2195   | 0.653717      |
# | Voting Classifier    | 63       | 72.4138    | 42     | 53.1646   | 0.650145      |
# | Bagging Classifier   | 53       | 53.3333    | 48     | 50.5263   | 0.589459      |
# | XGBoost Classifier   | 58       | 61.1111    | 44     | 51.1628   | 0.590248      |
# | LightGBM             | 59       | 63.6364    | 42     | 50.6024   | 0.598184      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.62     | 0.666667   | 0.4    | 0.5       | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.62     | 0.473684   | 0.36   | 0.409091  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.59     | 0.5        | 0.42   | 0.456522  | {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 10}      |
# | SVM                  | 0.63     | 0.730769   | 0.38   | 0.5       | {'C': 100, 'kernel': 'rbf'}                                          |
# | Gradient Boosting    | 0.65     | 0.5        | 0.44   | 0.468085  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 3}             |
# | Neural Network       | 0.64     | 0.75       | 0.42   | 0.538462  | {'hidden_layer_sizes': (100, 100), 'alpha': 0.1}                     |
# | Voting Classifier    | 0.63     | 0.724138   | 0.42   | 0.531646  | {}                                                                    |
# | Bagging Classifier   | 0.55     | 0.521739   | 0.48   | 0.5       | {'n_estimators': 200, 'max_samples': 0.5}                            |
# | XGBoost Classifier   | 0.63     | 0.512195   | 0.42   | 0.461538  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3}           |
# | LightGBM             | 0.64     | 0.552632   | 0.42   | 0.477273  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3}         |

# %% [markdown]
# 7. 2
#
# purpose：dummy
# log：IQRVars
# std：min-max scaling
# select：lasso->   'credit.policy', 'int.rate', 'fico', 'inq.last.6mths', 'purpose_credit_card', 'purpose_small_business'
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 61       | 65.7143    | 46     | 54.1176   | 0.653715      |
# | Decision Tree        | 49       | 48.9796    | 48     | 48.4848   | 0.573587      |
# | Random Forest        | 51       | 51.3514    | 38     | 43.6782   | 0.595402      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.648558      |
# | Gradient Boosting    | 59       | 63.6364    | 42     | 50.6024   | 0.639833      |
# | Neural Network       | 60       | 63.8889    | 46     | 53.4884   | 0.652527      |
# | Voting Classifier    | 60       | 65.625     | 42     | 51.2195   | 0.654904      |
# | Bagging Classifier   | 54       | 55.2632    | 42     | 47.7273   | 0.591039      |
# | XGBoost Classifier   | 64       | 73.3333    | 44     | 55        | 0.594613      |
# | LightGBM             | 60       | 66.6667    | 40     | 50        | 0.612462      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.61     | 0.657143   | 0.46   | 0.541176  | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.62     | 0.545455   | 0.48   | 0.510638  | {'max_depth': 10, 'min_samples_split': 5}                            |
# | Random Forest        | 0.61     | 0.645161   | 0.4    | 0.493827  | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5}        |
# | SVM                  | 0.63     | 0.740741   | 0.4    | 0.519481  | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.65     | 0.568182   | 0.5    | 0.531915  | {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7}          |
# | Neural Network       | 0.65     | 0.777778   | 0.42   | 0.545455  | {'hidden_layer_sizes': (100, 100), 'alpha': 0.1}                     |
# | Voting Classifier    | 0.61     | 0.677419   | 0.42   | 0.518519  | {}                                                                    |
# | Bagging Classifier   | 0.59     | 0.512821   | 0.4    | 0.449438  | {'n_estimators': 10, 'max_samples': 0.7}                             |
# | XGBoost Classifier   | 0.65     | 0.594595   | 0.44   | 0.505747  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 5}             |
# | LightGBM             | 0.65     | 0.488889   | 0.44   | 0.463158  | {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 9}           |

# %% [markdown]
# 7. 3
#
# purpose：dummy
# log：IQRVars
# std：min-max scaling
# select：kbest12  ->  'credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', 'pub.rec', 'purpose_credit_card', 'purpose_small_business'
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 59       | 65.5172    | 38     | 48.1013   | 0.651727      |
# | Decision Tree        | 57       | 57.1429    | 56     | 56.5657   | 0.563667      |
# | Random Forest        | 59       | 63.6364    | 42     | 50.6024   | 0.618805      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.647369      |
# | Gradient Boosting    | 55       | 56.7568    | 42     | 48.2759   | 0.62991       |
# | Neural Network       | 56       | 60         | 36     | 45        | 0.646575      |
# | Voting Classifier    | 61       | 67.7419    | 42     | 51.8519   | 0.649345      |
# | Bagging Classifier   | 65       | 70.2703    | 52     | 59.7701   | 0.61762       |
# | XGBoost Classifier   | 59       | 60.4651    | 52     | 55.914    | 0.593017      |
# | LightGBM             | 58       | 60         | 48     | 53.3333   | 0.603729      |
#
#
# - model_CVscore_maximum
#
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.59     | 0.615385   | 0.32   | 0.421053  | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.6      | 0.565217   | 0.52   | 0.541667  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.63     | 0.605263   | 0.46   | 0.522727  | {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 5}        |
# | SVM                  | 0.61     | 0.655172   | 0.38   | 0.481013  | {'C': 0.1, 'kernel': 'linear'}                                       |
# | Gradient Boosting    | 0.63     | 0.55       | 0.44   | 0.488889  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 5}             |
# | Neural Network       | 0.62     | 0.6        | 0.24   | 0.342857  | {'hidden_layer_sizes': (100, 100), 'alpha': 0.001}                   |
# | Voting Classifier    | 0.59     | 0.636364   | 0.42   | 0.506024  | {}                                                                    |
# | Bagging Classifier   | 0.65     | 0.638889   | 0.46   | 0.534884  | {'n_estimators': 100, 'max_samples': 1.0}                            |
# | XGBoost Classifier   | 0.67     | 0.636364   | 0.56   | 0.595745  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 5}             |
# | LightGBM             | 0.64     | 0.575      | 0.46   | 0.511111  | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}            |

# %% [markdown]
# 7. 4
#
# purpose：dummy
# log：IQRVars
# std：min-max scaling
# select：ridge (all)
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 60       | 65.625     | 42     | 51.2195   | 0.652914      |
# | Decision Tree        | 65       | 67.4419    | 58     | 62.3656   | 0.557722      |
# | Random Forest        | 62       | 64.2857    | 54     | 58.6957   | 0.623164      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.645783      |
# | Gradient Boosting    | 61       | 72         | 36     | 48        | 0.638244      |
# | Neural Network       | 59       | 63.6364    | 42     | 50.6024   | 0.647762      |
# | Voting Classifier    | 60       | 65.625     | 42     | 51.2195   | 0.650541      |
# | Bagging Classifier   | 61       | 64.8649    | 48     | 55.1724   | 0.621581      |
# | XGBoost Classifier   | 67       | 74.2857    | 52     | 61.1765   | 0.608489      |
# | LightGBM             | 61       | 64.8649    | 48     | 55.1724   | 0.609283      |
#
#
# - model_CVscore_maximum
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.61     | 0.666667   | 0.32   | 0.432432  | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.68     | 0.617021   | 0.58   | 0.597938  | {'max_depth': None, 'min_samples_split': 10}                         |
# | Random Forest        | 0.64     | 0.628571   | 0.44   | 0.517647  | {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 2}       |
# | SVM                  | 0.61     | 0.678571   | 0.38   | 0.487179  | {'C': 0.1, 'kernel': 'linear'}                                       |
# | Gradient Boosting    | 0.67     | 0.571429   | 0.4    | 0.470588  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5}         |
# | Neural Network       | 0.62     | 0.666667   | 0.32   | 0.432432  | {'hidden_layer_sizes': (50,), 'alpha': 0.1}                          |
# | Voting Classifier    | 0.61     | 0.666667   | 0.44   | 0.53012   | {}                                                                    |
# | Bagging Classifier   | 0.66     | 0.666667   | 0.44   | 0.53012   | {'n_estimators': 50, 'max_samples': 1.0}                             |
# | XGBoost Classifier   | 0.66     | 0.636364   | 0.56   | 0.595745  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 5}             |
# | LightGBM             | 0.7      | 0.710526   | 0.54   | 0.613636  | {'n_estimators': 200, 'learning_rate': 1, 'max_depth': 7}            |

# %% [markdown]
# ------------

# %% [markdown]
# 8. 1
#
# purpose：dummy
# log：logVars
# std：min-max scaling
# select：forward->'int.rate', 'inq.last.6mths', 'purpose_small_business', 'dti', 'purpose_credit_card'
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 59       | 65.5172    | 38     | 48.1013   | 0.643794      |
# | Decision Tree        | 56       | 56.8182    | 50     | 53.1915   | 0.572792      |
# | Random Forest        | 59       | 62.8571    | 44     | 51.7647   | 0.583505      |
# | SVM                  | 60       | 72.7273    | 32     | 44.4444   | 0.636656      |
# | Gradient Boosting    | 59       | 68         | 34     | 45.3333   | 0.62754       |
# | Neural Network       | 57       | 62.069     | 36     | 45.5696   | 0.644595      |
# | Voting Classifier    | 60       | 69.2308    | 36     | 47.3684   | 0.633484      |
# | Bagging Classifier   | 56       | 57.5       | 46     | 51.1111   | 0.588656      |
# | XGBoost Classifier   | 61       | 65.7143    | 46     | 54.1176   | 0.598983      |
# | LightGBM             | 61       | 66.6667    | 44     | 53.012    | 0.601751      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.61     | 0.655172   | 0.38   | 0.481013  | {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.59     | 0.53125    | 0.34   | 0.414634  | {'max_depth': 20, 'min_samples_split': 2}                            |
# | Random Forest        | 0.61     | 0.588235   | 0.4    | 0.47619   | {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5}        |
# | SVM                  | 0.6      | 0.764706   | 0.26   | 0.38806   | {'C': 0.1, 'kernel': 'linear'}                                       |
# | Gradient Boosting    | 0.63     | 0.531915   | 0.5    | 0.515464  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 9}             |
# | Neural Network       | 0.61     | 0.692308   | 0.36   | 0.473684  | {'hidden_layer_sizes': (100, 100), 'alpha': 0.01}                    |
# | Voting Classifier    | 0.61     | 0.703704   | 0.38   | 0.493506  | {}                                                                    |
# | Bagging Classifier   | 0.62     | 0.578947   | 0.44   | 0.5       | {'n_estimators': 200, 'max_samples': 0.7}                            |
# | XGBoost Classifier   | 0.65     | 0.595238   | 0.5    | 0.543478  | {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 3}          |
# | LightGBM             | 0.64     | 0.648649   | 0.48   | 0.551724  | {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5}          |

# %% [markdown]
# 8. 2
#
# purpose：dummy
# log：logVars
# std：min-max scaling
# select：lasso：'credit.policy', 'int.rate', 'fico', 'inq.last.6mths' , 'purpose_credit_card', 'purpose_small_business'
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 61       | 65.7143    | 46     | 54.1176   | 0.654112      |
# | Decision Tree        | 56       | 56.25      | 54     | 55.102    | 0.572         |
# | Random Forest        | 57       | 60.6061    | 40     | 48.1928   | 0.596194      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.648954      |
# | Gradient Boosting    | 59       | 63.6364    | 42     | 50.6024   | 0.639833      |
# | Neural Network       | 60       | 63.8889    | 46     | 53.4884   | 0.650145      |
# | Voting Classifier    | 60       | 65.625     | 42     | 51.2195   | 0.652526      |
# | Bagging Classifier   | 56       | 58.8235    | 42     | 47.619    | 0.593421      |
# | XGBoost Classifier   | 59       | 63.6364    | 42     | 50.6024   | 0.594613      |
# | LightGBM             | 63       | 68.5714    | 48     | 56.4706   | 0.612462      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.62     | 0.657143   | 0.46   | 0.541176  | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.62     | 0.627907   | 0.54   | 0.580645  | {'max_depth': 10, 'min_samples_split': 5}                            |
# | Random Forest        | 0.62     | 0.709677   | 0.44   | 0.54321   | {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 10}    |
# | SVM                  | 0.63     | 0.740741   | 0.4    | 0.519481  | {'C': 10, 'kernel': 'rbf'}                                           |
# | Gradient Boosting    | 0.64     | 0.615385   | 0.48   | 0.539326  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 9}             |
# | Neural Network       | 0.65     | 0.777778   | 0.42   | 0.545455  | {'hidden_layer_sizes': (100, 100), 'alpha': 0.1}                     |
# | Voting Classifier    | 0.61     | 0.677419   | 0.42   | 0.518519  | {}                                                                    |
# | Bagging Classifier   | 0.64     | 0.575758   | 0.38   | 0.457831  | {'n_estimators': 100, 'max_samples': 0.5}                            |
# | XGBoost Classifier   | 0.65     | 0.588235   | 0.4    | 0.47619   | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 3}            |
# | LightGBM             | 0.7      | 0.577778   | 0.52   | 0.547368  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 3}             |

# %% [markdown]
# 8. 3
#
# purpose：dummy
# log：logVars
# std：min-max scaling
# select：kbest10->'credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti', 'fico', 'days.with.cr.line', 'revol.util', 'inq.last.6mths', 'pub.rec', 'purpose_credit_card', 'purpose_small_business'
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 57       | 62.069     | 36     | 45.5696   | 0.652521      |
# | Decision Tree        | 56       | 56.25      | 54     | 55.102    | 0.561289      |
# | Random Forest        | 53       | 54.2857    | 38     | 44.7059   | 0.619993      |
# | SVM                  | 61       | 68.9655    | 40     | 50.6329   | 0.64856       |
# | Gradient Boosting    | 55       | 56.7568    | 42     | 48.2759   | 0.62991       |
# | Neural Network       | 56       | 60.7143    | 34     | 43.5897   | 0.646576      |
# | Voting Classifier    | 60       | 66.6667    | 40     | 50        | 0.65133       |
# | Bagging Classifier   | 63       | 66.6667    | 52     | 58.427    | 0.617223      |
# | XGBoost Classifier   | 57       | 57.7778    | 52     | 54.7368   | 0.593017      |
# | LightGBM             | 58       | 60.5263    | 46     | 52.2727   | 0.604125      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.6      | 0.615385   | 0.32   | 0.421053  | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.6      | 0.553191   | 0.52   | 0.536082  | {'max_depth': 5, 'min_samples_split': 2}                             |
# | Random Forest        | 0.61     | 0.6        | 0.48   | 0.533333  | {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 5}       |
# | SVM                  | 0.61     | 0.666667   | 0.4    | 0.5       | {'C': 0.1, 'kernel': 'linear'}                                       |
# | Gradient Boosting    | 0.66     | 0.581395   | 0.5    | 0.537634  | {'n_estimators': 50, 'learning_rate': 1, 'max_depth': 5}             |
# | Neural Network       | 0.59     | 0.645161   | 0.4    | 0.493827  | {'hidden_layer_sizes': (50,), 'alpha': 0.001}                        |
# | Voting Classifier    | 0.59     | 0.645161   | 0.4    | 0.493827  | {}                                                                    |
# | Bagging Classifier   | 0.65     | 0.657143   | 0.46   | 0.541176  | {'n_estimators': 100, 'max_samples': 0.5}                            |
# | XGBoost Classifier   | 0.65     | 0.630435   | 0.58   | 0.604167  | {'n_estimators': 100, 'learning_rate': 1, 'max_depth': 7}            |
# | LightGBM             | 0.63     | 0.605263   | 0.46   | 0.522727  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3}         |

# %% [markdown]
# 8. 4
#
# purpose：dummy
# log：logVars
# std：min-max scaling
# select：ridge(all)
#
#
# - easy_model
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Mean CV Score |
# |----------------------|----------|------------|--------|-----------|---------------|
# | Logistic Regression  | 58       | 64.2857    | 36     | 46.1538   | 0.654895      |
# | Decision Tree        | 63       | 64.4444    | 58     | 61.0526   | 0.558119      |
# | Random Forest        | 63       | 66.6667    | 52     | 58.427    | 0.625147      |
# | SVM                  | 62       | 71.4286    | 40     | 51.2821   | 0.645387      |
# | Gradient Boosting    | 60       | 70.8333    | 34     | 45.9459   | 0.63864       |
# | Neural Network       | 56       | 59.375     | 38     | 46.3415   | 0.646571      |
# | Voting Classifier    | 59       | 64.5161    | 40     | 49.3827   | 0.648555      |
# | Bagging Classifier   | 64       | 69.4444    | 50     | 58.1395   | 0.621979      |
# | XGBoost Classifier   | 62       | 66.6667    | 48     | 55.814    | 0.608489      |
# | LightGBM             | 59       | 62.8571    | 44     | 51.7647   | 0.609283      |
#
#
# - model_CVscore_maximum
#
#
#
# - model_accuracy_maximum
#
# | Model                | Accuracy | Precision  | Recall | F1-score  | Best Parameters                                                      |
# |----------------------|----------|------------|--------|-----------|-----------------------------------------------------------------------|
# | Logistic Regression  | 0.6      | 0.68       | 0.34   | 0.453333  | {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}                   |
# | Decision Tree        | 0.67     | 0.617021   | 0.58   | 0.597938  | {'max_depth': None, 'min_samples_split': 10}                         |
# | Random Forest        | 0.64     | 0.636364   | 0.42   | 0.506024  | {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 2}       |
# | SVM                  | 0.62     | 0.645161   | 0.4    | 0.493827  | {'C': 1, 'kernel': 'rbf'}                                            |
# | Gradient Boosting    | 0.67     | 0.588235   | 0.4    | 0.47619   | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5}         |
# | Neural Network       | 0.6      | 0.607143   | 0.34   | 0.435897  | {'hidden_layer_sizes': (50,), 'alpha': 0.001}                        |
# | Voting Classifier    | 0.59     | 0.645161   | 0.4    | 0.493827  | {}                                                                    |
# | Bagging Classifier   | 0.64     | 0.676471   | 0.46   | 0.547619  | {'n_estimators': 10, 'max_samples': 1.0}                             |
# | XGBoost Classifier   | 0.65     | 0.642857   | 0.54   | 0.586957  | {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}         |
# | LightGBM             | 0.66     | 0.7        | 0.56   | 0.622222  | {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5}         |

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
